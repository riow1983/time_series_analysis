# %%
#!pip install fbprophet
#!conda install gcc --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /anaconda
#
#   added / updated specs:
#     - gcc
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asn1crypto-0.24.0          |           py36_0         154 KB
#     ca-certificates-2019.1.23  |                0         126 KB
#     certifi-2019.3.9           |           py36_0         155 KB
#     cloog-0.18.0               |                0         115 KB
#     conda-4.6.8                |           py36_0         1.7 MB
#     cryptography-2.6.1         |   py36ha12b0ac_0         576 KB
#     curl-7.64.0                |       ha441bb4_2         147 KB
#     gcc-4.8.5                  |                8        55.1 MB
#     gmp-6.1.2                  |       hb37e062_1         734 KB
#     isl-0.12.2                 |                1         933 KB
#     krb5-1.16.1                |       hddcf347_7         1.1 MB
#     libcurl-7.64.0             |       h051b688_2         531 KB
#     libedit-3.1.20181209       |       hb402a30_0         159 KB
#     libssh2-1.8.0              |       ha12b0ac_4         218 KB
#     mpc-1.0.3                  |       h7a72875_5          88 KB
#     mpfr-3.1.5                 |       h711e7fd_2         423 KB
#     ncurses-6.1                |       h0a44026_1         887 KB
#     openssl-1.1.1b             |       h1de35cc_1         3.4 MB
#     pycurl-7.43.0.2            |   py36ha12b0ac_0         185 KB
#     python-3.6.8               |       haf84260_0        20.5 MB
#     sqlite-3.27.2              |       ha441bb4_0         2.3 MB
#     ------------------------------------------------------------
#                                            Total:        89.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   asn1crypto         pkgs/main/osx-64::asn1crypto-0.24.0-py36_0
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2019.1.23-0
#   cloog              pkgs/free/osx-64::cloog-0.18.0-0
#   gcc                pkgs/free/osx-64::gcc-4.8.5-8
#   gmp                pkgs/main/osx-64::gmp-6.1.2-hb37e062_1
#   isl                pkgs/free/osx-64::isl-0.12.2-1
#   krb5               pkgs/main/osx-64::krb5-1.16.1-hddcf347_7
#   libcurl            pkgs/main/osx-64::libcurl-7.64.0-h051b688_2
#   libcxx             pkgs/main/osx-64::libcxx-4.0.1-hcfea43d_1
#   libcxxabi          pkgs/main/osx-64::libcxxabi-4.0.1-hcfea43d_1
#   libedit            pkgs/main/osx-64::libedit-3.1.20181209-hb402a30_0
#   libffi             pkgs/main/osx-64::libffi-3.2.1-h475c297_4
#   libssh2            pkgs/main/osx-64::libssh2-1.8.0-ha12b0ac_4
#   mpc                pkgs/main/osx-64::mpc-1.0.3-h7a72875_5
#   mpfr               pkgs/main/osx-64::mpfr-3.1.5-h711e7fd_2
#   ncurses            pkgs/main/osx-64::ncurses-6.1-h0a44026_1
#
# The following packages will be UPDATED:
#
#   certifi                                 2018.11.29-py36_0 --> 2019.3.9-py36_0
#   conda                                        4.6.7-py36_0 --> 4.6.8-py36_0
#   cryptography         pkgs/free::cryptography-1.7.1-py36_0 --> pkgs/main::cryptography-2.6.1-py36ha12b0ac_0
#   curl                             pkgs/free::curl-7.52.1-0 --> pkgs/main::curl-7.64.0-ha441bb4_2
#   openssl                       pkgs/free::openssl-1.0.2k-1 --> pkgs/main::openssl-1.1.1b-h1de35cc_1
#   pycurl                    pkgs/free::pycurl-7.43.0-py36_2 --> pkgs/main::pycurl-7.43.0.2-py36ha12b0ac_0
#   python                          pkgs/free::python-3.6.0-0 --> pkgs/main::python-3.6.8-haf84260_0
#   readline                        pkgs/free::readline-6.2-2 --> pkgs/main::readline-7.0-h1de35cc_5
#   sqlite                         pkgs/free::sqlite-3.13.0-0 --> pkgs/main::sqlite-3.27.2-ha441bb4_0
#   tk                                 pkgs/free::tk-8.5.18-0 --> pkgs/main::tk-8.6.8-ha441bb4_0
#   xz                                  pkgs/free::xz-5.2.2-1 --> pkgs/main::xz-5.2.4-h1de35cc_4
#   zlib                              pkgs/free::zlib-1.2.8-3 --> pkgs/main::zlib-1.2.11-h1de35cc_3
#
#
# Proceed ([y]/n)? ^C
#
#
# Operation aborted.  Exiting.

# %%
# !conda install -c conda-forge fbprophet --yes
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.7
#   latest version: 4.6.8
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /anaconda
#
#   added / updated specs:
#     - fbprophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asn1crypto-0.24.0          |        py36_1003         154 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     cctools-895                |       h7512d6f_0         1.5 MB  conda-forge
#     certifi-2019.3.9           |           py36_0         149 KB  conda-forge
#     clang-4.0.1                |       h662ec87_0        73.7 MB  conda-forge
#     clang_osx-64-4.0.1         |      h1ce6c1d_11           7 KB
#     clangxx-4.0.1              |       hc9b4283_0          10 KB
#     clangxx_osx-64-4.0.1       |      h22b1bf0_11           7 KB
#     compiler-rt-4.0.1          |       h5487866_0         963 KB  conda-forge
#     conda-4.6.8                |           py36_0         876 KB  conda-forge
#     convertdate-2.1.3          |          py_1000          30 KB  conda-forge
#     cryptography-2.6.1         |   py36h212c5bf_0         564 KB  conda-forge
#     curl-7.64.1                |       h22ea746_0         122 KB  conda-forge
#     ephem-3.7.6.0              |py36h1de35cc_1001         679 KB  conda-forge
#     fbprophet-0.4.post2        |   py36h0a44026_0         618 KB  conda-forge
#     holidays-0.9.10            |             py_0          36 KB  conda-forge
#     krb5-1.16.3                |    hcfa6398_1001         1.1 MB  conda-forge
#     ld64-274.2                 |       h7c2db76_0         2.6 MB  conda-forge
#     libcurl-7.64.1             |       h16faf7d_0         525 KB  conda-forge
#     libcxx-4.0.1               |       h579ed51_0         957 KB
#     libcxxabi-4.0.1            |       hebd6815_0         149 KB
#     libedit-3.1.20170329       |    hcfe32e1_1001         152 KB  conda-forge
#     libffi-3.2.1               |    h6de7cb9_1006          43 KB  conda-forge
#     libssh2-1.8.2              |       hcdc9a53_2         221 KB  conda-forge
#     llvm-4.0.1                 |       hc748206_0       136.7 MB  conda-forge
#     llvm-lto-tapi-4.0.1        |       h6701bc3_0        11.7 MB  conda-forge
#     lunardate-0.2.0            |             py_0          21 KB  conda-forge
#     ncurses-6.1                |    h0a44026_1002         1.3 MB  conda-forge
#     openssl-1.1.1b             |       h01d97ff_2         3.5 MB  conda-forge
#     pandas-0.23.4              |py36h1702cab_1000         9.1 MB  conda-forge
#     pycurl-7.43.0.2            |   py36ha12b0ac_0         185 KB
#     pystan-2.17.1.0            |py36h1702cab_1003        14.2 MB  conda-forge
#     python-3.6.7               |    h8dc6b48_1004        20.5 MB  conda-forge
#     readline-7.0               |    hcfe32e1_1001         393 KB  conda-forge
#     sqlite-3.26.0              |    h1765d9f_1001         2.4 MB  conda-forge
#     tk-8.6.9                   |    ha441bb4_1001         3.2 MB  conda-forge
#     xz-5.2.4                   |    h1de35cc_1001         268 KB  conda-forge
#     zlib-1.2.11                |    h1de35cc_1004         101 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       288.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   asn1crypto         conda-forge/osx-64::asn1crypto-0.24.0-py36_1003
#   ca-certificates    conda-forge/osx-64::ca-certificates-2019.3.9-hecc5488_0
#   cctools            conda-forge/osx-64::cctools-895-h7512d6f_0
#   clang              conda-forge/osx-64::clang-4.0.1-h662ec87_0
#   clang_osx-64       pkgs/main/osx-64::clang_osx-64-4.0.1-h1ce6c1d_11
#   clangxx            pkgs/main/osx-64::clangxx-4.0.1-hc9b4283_0
#   clangxx_osx-64     pkgs/main/osx-64::clangxx_osx-64-4.0.1-h22b1bf0_11
#   compiler-rt        conda-forge/osx-64::compiler-rt-4.0.1-h5487866_0
#   convertdate        conda-forge/noarch::convertdate-2.1.3-py_1000
#   ephem              conda-forge/osx-64::ephem-3.7.6.0-py36h1de35cc_1001
#   fbprophet          conda-forge/osx-64::fbprophet-0.4.post2-py36h0a44026_0
#   holidays           conda-forge/noarch::holidays-0.9.10-py_0
#   krb5               conda-forge/osx-64::krb5-1.16.3-hcfa6398_1001
#   ld64               conda-forge/osx-64::ld64-274.2-h7c2db76_0
#   libcurl            conda-forge/osx-64::libcurl-7.64.1-h16faf7d_0
#   libcxx             pkgs/main/osx-64::libcxx-4.0.1-h579ed51_0
#   libcxxabi          pkgs/main/osx-64::libcxxabi-4.0.1-hebd6815_0
#   libedit            conda-forge/osx-64::libedit-3.1.20170329-hcfe32e1_1001
#   libffi             conda-forge/osx-64::libffi-3.2.1-h6de7cb9_1006
#   libssh2            conda-forge/osx-64::libssh2-1.8.2-hcdc9a53_2
#   llvm               conda-forge/osx-64::llvm-4.0.1-hc748206_0
#   llvm-lto-tapi      conda-forge/osx-64::llvm-lto-tapi-4.0.1-h6701bc3_0
#   lunardate          conda-forge/noarch::lunardate-0.2.0-py_0
#   ncurses            conda-forge/osx-64::ncurses-6.1-h0a44026_1002
#   pystan             conda-forge/osx-64::pystan-2.17.1.0-py36h1702cab_1003
#
# The following packages will be UPDATED:
#
#   certifi              pkgs/main::certifi-2018.11.29-py36_0 --> conda-forge::certifi-2019.3.9-py36_0
#   conda                       pkgs/main::conda-4.6.7-py36_0 --> conda-forge::conda-4.6.8-py36_0
#   cryptography         pkgs/free::cryptography-1.7.1-py36_0 --> conda-forge::cryptography-2.6.1-py36h212c5bf_0
#   curl                             pkgs/free::curl-7.52.1-0 --> conda-forge::curl-7.64.1-h22ea746_0
#   openssl                       pkgs/free::openssl-1.0.2k-1 --> conda-forge::openssl-1.1.1b-h01d97ff_2
#   pandas               pkgs/free::pandas-0.19.2-np111py36_1 --> conda-forge::pandas-0.23.4-py36h1702cab_1000
#   pycurl                    pkgs/free::pycurl-7.43.0-py36_2 --> pkgs/main::pycurl-7.43.0.2-py36ha12b0ac_0
#   python                          pkgs/free::python-3.6.0-0 --> conda-forge::python-3.6.7-h8dc6b48_1004
#   readline                        pkgs/free::readline-6.2-2 --> conda-forge::readline-7.0-hcfe32e1_1001
#   sqlite                         pkgs/free::sqlite-3.13.0-0 --> conda-forge::sqlite-3.26.0-h1765d9f_1001
#   tk                                 pkgs/free::tk-8.5.18-0 --> conda-forge::tk-8.6.9-ha441bb4_1001
#   xz                                  pkgs/free::xz-5.2.2-1 --> conda-forge::xz-5.2.4-h1de35cc_1001
#   zlib                              pkgs/free::zlib-1.2.8-3 --> conda-forge::zlib-1.2.11-h1de35cc_1004
#
#
#
# Downloading and Extracting Packages
# pandas-0.23.4        | 9.1 MB    | ##################################### | 100%
# cctools-895          | 1.5 MB    | ##################################### | 100%
# lunardate-0.2.0      | 21 KB     | ##################################### | 100%
# zlib-1.2.11          | 101 KB    | ##################################### | 100%
# ld64-274.2           | 2.6 MB    | ##################################### | 100%
# libcxx-4.0.1         | 957 KB    | ##################################### | 100%
# xz-5.2.4             | 268 KB    | ##################################### | 100%
# asn1crypto-0.24.0    | 154 KB    | ##################################### | 100%
# krb5-1.16.3          | 1.1 MB    | ##################################### | 100%
# clangxx-4.0.1        | 10 KB     | ##################################### | 100%
# readline-7.0         | 393 KB    | ##################################### | 100%
# fbprophet-0.4.post2  | 618 KB    | ##################################### | 100%
# libssh2-1.8.2        | 221 KB    | ##################################### | 100%
# clangxx_osx-64-4.0.1 | 7 KB      | ##################################### | 100%
# sqlite-3.26.0        | 2.4 MB    | ##################################### | 100%
# certifi-2019.3.9     | 149 KB    | ##################################### | 100%
# pystan-2.17.1.0      | 14.2 MB   | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# ephem-3.7.6.0        | 679 KB    | ##################################### | 100%
# holidays-0.9.10      | 36 KB     | ##################################### | 100%
# libcxxabi-4.0.1      | 149 KB    | ##################################### | 100%
# openssl-1.1.1b       | 3.5 MB    | ##################################### | 100%
# clang_osx-64-4.0.1   | 7 KB      | ##################################### | 100%
# conda-4.6.8          | 876 KB    | ##################################### | 100%
# libedit-3.1.20170329 | 152 KB    | ##################################### | 100%
# curl-7.64.1          | 122 KB    | ##################################### | 100%
# convertdate-2.1.3    | 30 KB     | ##################################### | 100%
# llvm-4.0.1           | 136.7 MB  | ##################################### | 100%
# clang-4.0.1          | 73.7 MB   | ##################################### | 100%
# tk-8.6.9             | 3.2 MB    | ##################################### | 100%
# python-3.6.7         | 20.5 MB   | ##################################### | 100%
# pycurl-7.43.0.2      | 185 KB    | ##################################### | 100%
# compiler-rt-4.0.1    | 963 KB    | ##################################### | 100%
# ncurses-6.1          | 1.3 MB    | ##################################### | 100%
# libffi-3.2.1         | 43 KB     | ##################################### | 100%
# cryptography-2.6.1   | 564 KB    | ##################################### | 100%
# libcurl-7.64.1       | 525 KB    | ##################################### | 100%
# llvm-lto-tapi-4.0.1  | 11.7 MB   | ##################################### | 100%
# done
# done
# done

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-af55e7023913> in <module>()
# ----> 1 import pandas as pd
#
# /anaconda/lib/python3.6/site-packages/pandas/__init__.py in <module>()
#      40 import pandas.core.config_init
#      41
# ---> 42 from pandas.core.api import *
#      43 from pandas.core.sparse.api import *
#      44 from pandas.tseries.api import *
#
# /anaconda/lib/python3.6/site-packages/pandas/core/api.py in <module>()
#       8 from pandas.core.dtypes.missing import isna, isnull, notna, notnull
#       9 from pandas.core.arrays import Categorical
# ---> 10 from pandas.core.groupby.groupby import Grouper
#      11 from pandas.io.formats.format import set_eng_float_format
#      12 from pandas.core.index import (Index, CategoricalIndex, Int64Index,
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/__init__.py in <module>()
#       1 # flake8: noqa
# ----> 2 from pandas.core.groupby.groupby import (
#       3     Grouper, GroupBy, SeriesGroupBy, DataFrameGroupBy
#       4 )
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in <module>()
#      47                                CategoricalIndex, _ensure_index)
#      48 from pandas.core.arrays import ExtensionArray, Categorical
# ---> 49 from pandas.core.frame import DataFrame
#      50 from pandas.core.generic import NDFrame, _shared_docs
#      51 from pandas.core.internals import BlockManager, make_block
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in <module>()
#      64
#      65
# ---> 66 from pandas.core.generic import NDFrame, _shared_docs
#      67 from pandas.core.index import (Index, MultiIndex, _ensure_index,
#      68                                _ensure_index_from_sequences)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in <module>()
#      38 from pandas.core.index import (Index, MultiIndex, _ensure_index,
#      39                                InvalidIndexError, RangeIndex)
# ---> 40 import pandas.core.indexing as indexing
#      41 from pandas.core.indexes.datetimes import DatetimeIndex
#      42 from pandas.core.indexes.period import PeriodIndex, Period
#
# AttributeError: module 'pandas' has no attribute 'core'

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-02b29c9bb76d> in <module>()
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from fbprophet import Prophet
#
# /anaconda/lib/python3.6/site-packages/pandas/__init__.py in <module>()
#      40 import pandas.core.config_init
#      41
# ---> 42 from pandas.core.api import *
#      43 from pandas.core.sparse.api import *
#      44 from pandas.tseries.api import *
#
# /anaconda/lib/python3.6/site-packages/pandas/core/api.py in <module>()
#       8 from pandas.core.dtypes.missing import isna, isnull, notna, notnull
#       9 from pandas.core.arrays import Categorical
# ---> 10 from pandas.core.groupby.groupby import Grouper
#      11 from pandas.io.formats.format import set_eng_float_format
#      12 from pandas.core.index import (Index, CategoricalIndex, Int64Index,
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/__init__.py in <module>()
#       1 # flake8: noqa
# ----> 2 from pandas.core.groupby.groupby import (
#       3     Grouper, GroupBy, SeriesGroupBy, DataFrameGroupBy
#       4 )
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in <module>()
#      47                                CategoricalIndex, _ensure_index)
#      48 from pandas.core.arrays import ExtensionArray, Categorical
# ---> 49 from pandas.core.frame import DataFrame
#      50 from pandas.core.generic import NDFrame, _shared_docs
#      51 from pandas.core.internals import BlockManager, make_block
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in <module>()
#      64
#      65
# ---> 66 from pandas.core.generic import NDFrame, _shared_docs
#      67 from pandas.core.index import (Index, MultiIndex, _ensure_index,
#      68                                _ensure_index_from_sequences)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in <module>()
#      41 from pandas.core.indexes.datetimes import DatetimeIndex
#      42 from pandas.core.indexes.period import PeriodIndex, Period
# ---> 43 from pandas.core.internals import BlockManager
#      44 import pandas.core.algorithms as algos
#      45 import pandas.core.common as com
#
# /anaconda/lib/python3.6/site-packages/pandas/core/internals/__init__.py in <module>()
#       1 # -*- coding: utf-8 -*-
# ----> 2 from .blocks import (  # noqa:F401
#       3     _block2d_to_blocknd, _factor_indexer, _block_shape,  # io.pytables
#       4     _safe_reshape,  # io.packers
#       5     make_block,     # io.pytables, io.packers
#
# /anaconda/lib/python3.6/site-packages/pandas/core/internals/blocks.py in <module>()
#       9
#      10 from pandas._libs import internals as libinternals, lib, tslib, tslibs
# ---> 11 from pandas._libs.tslibs import Timedelta, conversion, is_null_datetimelike
#      12 import pandas.compat as compat
#      13 from pandas.compat import range, zip
#
# ImportError: cannot import name 'Timedelta'
