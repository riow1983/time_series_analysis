# %%
""" reference: 
        https://qiita.com/GushiSnow/items/437dde3293f6d77bfa58 
        https://www.youtube.com/watch?v=JUctzSSAjG4 

"""
# Out:
# ' reference: \n        https://qiita.com/GushiSnow/items/437dde3293f6d77bfa58 \n        https://www.youtube.com/watch?v=JUctzSSAjG4 \n\n'

# %%
#!pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /anaconda/lib/python3.6/site-packages (19.0.3)

# %%
# !pip install pyflux
# Out:
# Collecting pyflux
#   Using cached https://files.pythonhosted.org/packages/37/e2/ac8ea14d34556e83a9fe9e23ba7b02ca14951849b9637c238ca83d04ac3c/pyflux-0.4.15.tar.gz
# Requirement already satisfied: numpy in /anaconda/lib/python3.6/site-packages (from pyflux) (1.14.5)
# Requirement already satisfied: pandas in /anaconda/lib/python3.6/site-packages (from pyflux) (0.19.2)
# Requirement already satisfied: scipy in /anaconda/lib/python3.6/site-packages (from pyflux) (1.2.1)
# Requirement already satisfied: numdifftools in /anaconda/lib/python3.6/site-packages (from pyflux) (0.9.20)
# Requirement already satisfied: patsy in /anaconda/lib/python3.6/site-packages (from pyflux) (0.4.1)
# Requirement already satisfied: python-dateutil>=2 in /anaconda/lib/python3.6/site-packages (from pandas->pyflux) (2.6.0)
# Requirement already satisfied: pytz>=2011k in /anaconda/lib/python3.6/site-packages (from pandas->pyflux) (2016.10)
# Requirement already satisfied: setuptools>=9.0 in /anaconda/lib/python3.6/site-packages (from numdifftools->pyflux) (40.8.0)
# Requirement already satisfied: algopy>=0.4 in /anaconda/lib/python3.6/site-packages (from numdifftools->pyflux) (0.5.7)
# Requirement already satisfied: six in /anaconda/lib/python3.6/site-packages (from patsy->pyflux) (1.10.0)
# Building wheels for collected packages: pyflux
# error
#   Complete output from command /anaconda/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/k2/1whlqmfj28z9kxvcyfh4cj3r0000gr/T/pip-install-wynkrop8/pyflux/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /private/var/folders/k2/1whlqmfj28z9kxvcyfh4cj3r0000gr/T/pip-wheel-kdmnxbmy --python-tag cp36:
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building extension "pyflux.__check_build._check_build" sources
#   building extension "pyflux.arma.arma_recursions" sources
#   building extension "pyflux.arma.nn_architecture" sources
#   building extension "pyflux.families.gas_recursions" sources
#   building extension "pyflux.families.poisson_kalman_recursions" sources
#   building extension "pyflux.garch.garch_recursions" sources
#   building extension "pyflux.gas.gas_core_recursions" sources
#   building extension "pyflux.gpnarx.kernel_routines" sources
#   building extension "pyflux.inference.metropolis_sampler" sources
#   building extension "pyflux.inference.bbvi_routines" sources
#   building extension "pyflux.ssm.kalman" sources
#   building extension "pyflux.var.var_recursions" sources
#   build_src: building npy-pkg config files
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux
#   copying pyflux/data_check.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#   copying pyflux/results.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#   copying pyflux/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#   copying pyflux/tsm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#   copying pyflux/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#   copying pyflux/latent_variables.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#   copying pyflux/covariances.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/__check_build
#   copying pyflux/__check_build/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/__check_build
#   copying pyflux/__check_build/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/__check_build
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#   copying pyflux/arma/arma.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#   copying pyflux/arma/nnarx.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#   copying pyflux/arma/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#   copying pyflux/arma/arimax.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#   copying pyflux/arma/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#   copying pyflux/arma/nnar.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_exponential.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_t.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_exponential.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_inference.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_poisson.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_skewt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_cauchy.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_laplace.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_laplace.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_skewt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_cauchy.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arimax_t.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_poisson.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   copying pyflux/arma/tests/test_arima_inference.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/ensembles
#   copying pyflux/ensembles/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ensembles
#   copying pyflux/ensembles/mixture_of_experts.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ensembles
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/inverse_gamma.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/laplace.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/truncated_normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/poisson.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/flat.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/exponential.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/cauchy.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/inverse_wishart.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/family.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/skewt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   copying pyflux/families/t.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/egarchm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/segarch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/egarchmreg.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/segarchm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/lmegarch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/egarch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   copying pyflux/garch/garch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/gas.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/gasreg.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/gasrank.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/gasx.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/gasllm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/scores.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   copying pyflux/gas/gasllt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#   copying pyflux/gpnarx/gpnarx.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#   copying pyflux/gpnarx/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#   copying pyflux/gpnarx/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#   copying pyflux/gpnarx/kernels.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#   copying pyflux/inference/metropolis_hastings.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#   copying pyflux/inference/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#   copying pyflux/inference/norm_post_sim.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#   copying pyflux/inference/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#   copying pyflux/inference/bbvi.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#   copying pyflux/inference/stoch_optim.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/output
#   copying pyflux/output/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/output
#   copying pyflux/output/tableprinter.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/output
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/ndynlin.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/local_trend.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/llt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/nllt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/nllm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/llm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/dynlin.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/dynamic_glm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/local_level.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   copying pyflux/ssm/dar.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/tests
#   copying pyflux/tests/nhst.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/tests
#   copying pyflux/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/tests
#   creating build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#   copying pyflux/var/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#   copying pyflux/var/var.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#   copying pyflux/var/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#   running build_ext
#   customize UnixCCompiler
#   customize UnixCCompiler using build_ext
#   building 'pyflux.__check_build._check_build' extension
#   compiling C sources
#   C compiler: gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/anaconda/include -arch x86_64 -I/anaconda/include -arch x86_64
#
#   creating build/temp.macosx-10.7-x86_64-3.6/pyflux
#   creating build/temp.macosx-10.7-x86_64-3.6/pyflux/__check_build
#   compile options: '-I/anaconda/lib/python3.6/site-packages/numpy/core/include -I/anaconda/include/python3.6m -c'
#   gcc: pyflux/__check_build/_check_build.c
#   In file included from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/syslimits.h:7,
#                    from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:34,
#                    from /anaconda/include/python3.6m/Python.h:11,
#                    from pyflux/__check_build/_check_build.c:4:
#   /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:194:15: fatal error: limits.h: No such file or directory
#    #include_next <limits.h>  /* recurse down to the real one */
#                  ^~~~~~~~~~
#   compilation terminated.
#   In file included from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/syslimits.h:7,
#                    from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:34,
#                    from /anaconda/include/python3.6m/Python.h:11,
#                    from pyflux/__check_build/_check_build.c:4:
#   /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:194:15: fatal error: limits.h: No such file or directory
#    #include_next <limits.h>  /* recurse down to the real one */
#                  ^~~~~~~~~~
#   compilation terminated.
#   error: Command "gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/anaconda/include -arch x86_64 -I/anaconda/include -arch x86_64 -I/anaconda/lib/python3.6/site-packages/numpy/core/include -I/anaconda/include/python3.6m -c pyflux/__check_build/_check_build.c -o build/temp.macosx-10.7-x86_64-3.6/pyflux/__check_build/_check_build.o -MMD -MF build/temp.macosx-10.7-x86_64-3.6/pyflux/__check_build/_check_build.o.d" failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for pyflux
#   Running setup.py clean for pyflux
# Failed to build pyflux
# Installing collected packages: pyflux
# error
#     Complete output from command /anaconda/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/k2/1whlqmfj28z9kxvcyfh4cj3r0000gr/T/pip-install-wynkrop8/pyflux/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/k2/1whlqmfj28z9kxvcyfh4cj3r0000gr/T/pip-record-yhlra8q8/install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building extension "pyflux.__check_build._check_build" sources
#     building extension "pyflux.arma.arma_recursions" sources
#     building extension "pyflux.arma.nn_architecture" sources
#     building extension "pyflux.families.gas_recursions" sources
#     building extension "pyflux.families.poisson_kalman_recursions" sources
#     building extension "pyflux.garch.garch_recursions" sources
#     building extension "pyflux.gas.gas_core_recursions" sources
#     building extension "pyflux.gpnarx.kernel_routines" sources
#     building extension "pyflux.inference.metropolis_sampler" sources
#     building extension "pyflux.inference.bbvi_routines" sources
#     building extension "pyflux.ssm.kalman" sources
#     building extension "pyflux.var.var_recursions" sources
#     build_src: building npy-pkg config files
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.6
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux
#     copying pyflux/data_check.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#     copying pyflux/results.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#     copying pyflux/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#     copying pyflux/tsm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#     copying pyflux/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#     copying pyflux/latent_variables.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#     copying pyflux/covariances.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/__check_build
#     copying pyflux/__check_build/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/__check_build
#     copying pyflux/__check_build/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/__check_build
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#     copying pyflux/arma/arma.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#     copying pyflux/arma/nnarx.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#     copying pyflux/arma/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#     copying pyflux/arma/arimax.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#     copying pyflux/arma/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#     copying pyflux/arma/nnar.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_exponential.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_t.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_exponential.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_inference.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_poisson.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_skewt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_cauchy.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_laplace.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_laplace.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_skewt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_cauchy.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arimax_t.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_poisson.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     copying pyflux/arma/tests/test_arima_inference.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/arma/tests
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/ensembles
#     copying pyflux/ensembles/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ensembles
#     copying pyflux/ensembles/mixture_of_experts.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ensembles
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/inverse_gamma.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/laplace.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/truncated_normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/normal.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/poisson.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/flat.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/exponential.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/cauchy.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/inverse_wishart.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/family.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/skewt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     copying pyflux/families/t.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/families
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/egarchm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/segarch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/egarchmreg.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/segarchm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/lmegarch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/egarch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     copying pyflux/garch/garch.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/garch
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/gas.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/gasreg.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/gasrank.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/gasx.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/gasllm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/scores.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     copying pyflux/gas/gasllt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gas
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#     copying pyflux/gpnarx/gpnarx.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#     copying pyflux/gpnarx/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#     copying pyflux/gpnarx/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#     copying pyflux/gpnarx/kernels.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/gpnarx
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#     copying pyflux/inference/metropolis_hastings.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#     copying pyflux/inference/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#     copying pyflux/inference/norm_post_sim.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#     copying pyflux/inference/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#     copying pyflux/inference/bbvi.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#     copying pyflux/inference/stoch_optim.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/inference
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/output
#     copying pyflux/output/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/output
#     copying pyflux/output/tableprinter.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/output
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/ndynlin.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/local_trend.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/llt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/nllt.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/nllm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/llm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/dynlin.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/dynamic_glm.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/local_level.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     copying pyflux/ssm/dar.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/ssm
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/tests
#     copying pyflux/tests/nhst.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/tests
#     copying pyflux/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/tests
#     creating build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#     copying pyflux/var/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#     copying pyflux/var/var.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#     copying pyflux/var/setup.py -> build/lib.macosx-10.7-x86_64-3.6/pyflux/var
#     running build_ext
#     customize UnixCCompiler
#     customize UnixCCompiler using build_ext
#     building 'pyflux.__check_build._check_build' extension
#     compiling C sources
#     C compiler: gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/anaconda/include -arch x86_64 -I/anaconda/include -arch x86_64
#
#     creating build/temp.macosx-10.7-x86_64-3.6/pyflux
#     creating build/temp.macosx-10.7-x86_64-3.6/pyflux/__check_build
#     compile options: '-I/anaconda/lib/python3.6/site-packages/numpy/core/include -I/anaconda/include/python3.6m -c'
#     gcc: pyflux/__check_build/_check_build.c
#     In file included from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/syslimits.h:7,
#                      from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:34,
#                      from /anaconda/include/python3.6m/Python.h:11,
#                      from pyflux/__check_build/_check_build.c:4:
#     /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:194:15: fatal error: limits.h: No such file or directory
#      #include_next <limits.h>  /* recurse down to the real one */
#                    ^~~~~~~~~~
#     compilation terminated.
#     In file included from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/syslimits.h:7,
#                      from /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:34,
#                      from /anaconda/include/python3.6m/Python.h:11,
#                      from pyflux/__check_build/_check_build.c:4:
#     /usr/local/Cellar/gcc/8.2.0/lib/gcc/8/gcc/x86_64-apple-darwin16.7.0/8.2.0/include-fixed/limits.h:194:15: fatal error: limits.h: No such file or directory
#      #include_next <limits.h>  /* recurse down to the real one */
#                    ^~~~~~~~~~
#     compilation terminated.
#     error: Command "gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/anaconda/include -arch x86_64 -I/anaconda/include -arch x86_64 -I/anaconda/lib/python3.6/site-packages/numpy/core/include -I/anaconda/include/python3.6m -c pyflux/__check_build/_check_build.c -o build/temp.macosx-10.7-x86_64-3.6/pyflux/__check_build/_check_build.o -MMD -MF build/temp.macosx-10.7-x86_64-3.6/pyflux/__check_build/_check_build.o.d" failed with exit status 1
#
#     ----------------------------------------
# Command "/anaconda/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/k2/1whlqmfj28z9kxvcyfh4cj3r0000gr/T/pip-install-wynkrop8/pyflux/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/k2/1whlqmfj28z9kxvcyfh4cj3r0000gr/T/pip-record-yhlra8q8/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /private/var/folders/k2/1whlqmfj28z9kxvcyfh4cj3r0000gr/T/pip-install-wynkrop8/pyflux/

# %%
import pyflux as pf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-7ca3cc2700b8> in <module>()
# ----> 1 import pyflux as pf
#
# ModuleNotFoundError: No module named 'pyflux'

# %%
import numpy as np
import pandas as pd
